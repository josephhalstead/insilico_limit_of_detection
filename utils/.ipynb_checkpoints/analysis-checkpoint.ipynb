# %%
import pandas as pd
import glob

# %%
sample_name = '180920_NB551319_0007_AH5GNLAFXY_18M05126-OS'


expected_variants_df = pd.read_csv('../misc/oncospanResults.txt', sep='\t', header=None, index_col=None)

# %%
expected_variants_df = expected_variants_df[[0,1,2,3]]
expected_variants_df.columns = ['CHROM', 'POS', 'REF', 'ALT']

# %%
def get_variant_key(df):
    
    return df['CHROM'] + '-' + str(df['POS']) + '-' + df['REF'] + '-' + df['ALT']

# %%
expected_variants_df['variant_key'] = expected_variants_df.apply(get_variant_key, axis=1)

# %%
expected_variants_df.head()
# Out:
#   CHROM        POS REF ALT       variant_key
# 0     1   27056285   G   A    1-27056285-G-A
# 1     1   27100181   C   T    1-27100181-C-T
# 2     1  115256530   G   T   1-115256530-G-T
# 3     1  156846233   G   A   1-156846233-G-A
# 4     1  156846307  GC   G  1-156846307-GC-G

# %%
variant_csvs = glob.glob('../output/csvs/*.csv')

master_variant_df = pd.DataFrame()

for csv in variant_csvs:
    
    new_df = pd.read_csv(csv, sep='\t')
    
    new_df['file_name'] = csv
    
    master_variant_df = master_variant_df.append(new_df)

# %%
master_variant_df['variant_key'] = master_variant_df.apply(get_variant_key, axis=1)

# %%
def get_variant_sample(df):
    
    return df['file_name'].split('/')[-1]

# %%
master_variant_df['variant_sample'] = master_variant_df.apply(get_variant_sample, axis=1)

# %%
def get_variant_down_sample_rate(df):
    
     return df['file_name'].split('/')[-1].split('_')[-2]

# %%
master_variant_df['variant_downsample_rate'] = master_variant_df.apply(get_variant_down_sample_rate, axis=1)

# %%
def get_variant_down_sample_replicate(df):
    
     return df['file_name'].split('/')[-1].split('_')[-1].split('.')[0]

# %%
master_variant_df['variant_downsample_rate_replicate'] = master_variant_df.apply(get_variant_down_sample_replicate, axis=1)

# %%
merged_list = []

for run in variant_csvs:
    
    for index, row in expected_variants_df.iterrows():
        
        merged_list.append([run, row[0], row[1], row[2], row[3], row[4]])

# %%
merged_df = pd.DataFrame(merged_list, columns=['file_name','CHROM', 'POS','REF', 'ALT', 'variant_key'])

# %%
merged_df.head()
# Out:
#                                            file_name CHROM        POS REF ALT  \
# 0  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...     1   27056285   G   A
# 1  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...     1   27100181   C   T
# 2  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...     1  115256530   G   T
# 3  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...     1  156846233   G   A
# 4  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...     1  156846307  GC   G
#
#         variant_key
# 0    1-27056285-G-A
# 1    1-27100181-C-T
# 2   1-115256530-G-T
# 3   1-156846233-G-A
# 4  1-156846307-GC-G

# %%
merged_df.head()
# Out:
#                                            file_name CHROM        POS REF ALT  \
# 0  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...     1   27056285   G   A
# 1  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...     1   27100181   C   T
# 2  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...     1  115256530   G   T
# 3  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...     1  156846233   G   A
# 4  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...     1  156846307  GC   G
#
#         variant_key
# 0    1-27056285-G-A
# 1    1-27100181-C-T
# 2   1-115256530-G-T
# 3   1-156846233-G-A
# 4  1-156846307-GC-G

# %%
master_variant_df.head()
# Out:
#   CHROM       POS REF ALT  DP  TLOD 18M05126-OS.AD 18M05126-OS.AF  \
# 0     1   1892043   G   A   2  8.52            0,2              1
# 1     1   1892048   G   C   2  8.52            0,2              1
# 2     1  11387192   G   C   3  6.38            1,2          0.667
# 3     1  12508943   A   G   3  6.97            1,2          0.667
# 4     1  13187294   T   C   4  6.13            1,2          0.625
#
#   18M05126-OS.GT 18M05126-OS.F1R2 18M05126-OS.F2R1  \
# 0            G/A              0,1              0,1
# 1            G/C              0,1              0,1
# 2            G/C              1,1              0,1
# 3            A/G              1,1              0,1
# 4            T/C              0,0              1,2
#
#                                            file_name     variant_key  \
# 0  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...   1-1892043-G-A
# 1  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...   1-1892048-G-C
# 2  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...  1-11387192-G-C
# 3  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...  1-12508943-A-G
# 4  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...  1-13187294-T-C
#
#                                       variant_sample variant_downsample_rate  \
# 0  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....                   0.005
# 1  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....                   0.005
# 2  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....                   0.005
# 3  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....                   0.005
# 4  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....                   0.005
#
#   variant_downsample_rate_replicate
# 0                                 1
# 1                                 1
# 2                                 1
# 3                                 1
# 4                                 1

# %%
final = pd.merge(merged_df, master_variant_df, on=['file_name','variant_key' ], how='left', )

# %%
final.head()
# Out:
#                                            file_name CHROM_x      POS_x REF_x  \
# 0  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...       1   27056285     G
# 1  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...       1   27100181     C
# 2  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...       1  115256530     G
# 3  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...       1  156846233     G
# 4  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...       1  156846307    GC
#
#   ALT_x       variant_key CHROM_y        POS_y REF_y ALT_y    DP   TLOD  \
# 0     A    1-27056285-G-A     NaN          NaN   NaN   NaN   NaN    NaN
# 1     T    1-27100181-C-T       1   27100181.0     C     T  10.0  10.82
# 2     T   1-115256530-G-T       1  115256530.0     G     T   5.0   5.62
# 3     A   1-156846233-G-A       1  156846233.0     G     A   9.0  13.21
# 4     G  1-156846307-GC-G       1  156846307.0    GC     G   9.0   7.06
#
#   18M05126-OS.AD 18M05126-OS.AF 18M05126-OS.GT 18M05126-OS.F1R2  \
# 0            NaN            NaN            NaN              NaN
# 1            5,4          0.454            C/T              3,2
# 2            3,2            0.4            G/T              2,0
# 3            5,4          0.444            G/A              1,3
# 4            5,3          0.389           GC/G              3,2
#
#   18M05126-OS.F2R1                                     variant_sample  \
# 0              NaN                                                NaN
# 1              2,2  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....
# 2              1,2  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....
# 3              4,1  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....
# 4              2,1  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....
#
#   variant_downsample_rate variant_downsample_rate_replicate
# 0                     NaN                               NaN
# 1                   0.005                                 1
# 2                   0.005                                 1
# 3                   0.005                                 1
# 4                   0.005                                 1

# %%
def get_sample_name(df):
    
    file_name = df['file_name'].split('/')[-1]
        
    split_file_name = file_name.split('_')
    
    return '_'.join(split_file_name[0:-2])

# %%
final['sample_name'] = final.apply(get_sample_name, axis=1)

# %%
final.head()
# Out:
#                                            file_name CHROM_x      POS_x REF_x  \
# 0  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...       1   27056285     G
# 1  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...       1   27100181     C
# 2  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...       1  115256530     G
# 3  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...       1  156846233     G
# 4  ../output/csvs/180920_NB551319_0007_AH5GNLAFXY...       1  156846307    GC
#
#   ALT_x       variant_key CHROM_y        POS_y REF_y ALT_y  \
# 0     A    1-27056285-G-A     NaN          NaN   NaN   NaN
# 1     T    1-27100181-C-T       1   27100181.0     C     T
# 2     T   1-115256530-G-T       1  115256530.0     G     T
# 3     A   1-156846233-G-A       1  156846233.0     G     A
# 4     G  1-156846307-GC-G       1  156846307.0    GC     G
#
#                       ...                        TLOD  18M05126-OS.AD  \
# 0                     ...                         NaN             NaN
# 1                     ...                       10.82             5,4
# 2                     ...                        5.62             3,2
# 3                     ...                       13.21             5,4
# 4                     ...                        7.06             5,3
#
#   18M05126-OS.AF 18M05126-OS.GT 18M05126-OS.F1R2 18M05126-OS.F2R1  \
# 0            NaN            NaN              NaN              NaN
# 1          0.454            C/T              3,2              2,2
# 2            0.4            G/T              2,0              1,2
# 3          0.444            G/A              1,3              4,1
# 4          0.389           GC/G              3,2              2,1
#
#                                       variant_sample variant_downsample_rate  \
# 0                                                NaN                     NaN
# 1  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....                   0.005
# 2  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....                   0.005
# 3  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....                   0.005
# 4  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS_0....                   0.005
#
#   variant_downsample_rate_replicate  \
# 0                               NaN
# 1                                 1
# 2                                 1
# 3                                 1
# 4                                 1
#
#                                    sample_name
# 0  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS
# 1  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS
# 2  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS
# 3  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS
# 4  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS
#
# [5 rows x 21 columns]

# %%
pivoted_df = final.pivot_table(index=['sample_name', 'variant_downsample_rate'], columns='variant_key', dropna=False, values=['DP', 'DP'],  aggfunc=['count', 'mean'])

# %%
pivoted_df.head()
# Out:
#                                                                               count  \
#                                                                                  DP
# variant_key                                                         1-115256530-G-T
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               1.0
#                                             0.01                                NaN
#                                             0.05                                2.0
#                                             0.1                                 2.0
#                                             0.25                                2.0
#
#                                                                                      \
#
# variant_key                                                         1-156846233-G-A
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               1.0
#                                             0.01                                2.0
#                                             0.05                                2.0
#                                             0.1                                 2.0
#                                             0.25                                2.0
#
#                                                                                       \
#
# variant_key                                                         1-156846307-GC-G
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                                2.0
#                                             0.01                                 2.0
#                                             0.05                                 2.0
#                                             0.1                                  2.0
#                                             0.25                                 2.0
#
#                                                                                      \
#
# variant_key                                                         1-156848995-C-T
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               2.0
#                                             0.01                                2.0
#                                             0.05                                2.0
#                                             0.1                                 2.0
#                                             0.25                                2.0
#
#                                                                                     \
#
# variant_key                                                         1-27056285-G-A
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                              NaN
#                                             0.01                               2.0
#                                             0.05                               2.0
#                                             0.1                                2.0
#                                             0.25                               2.0
#
#                                                                                     \
#
# variant_key                                                         1-27100181-C-T
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                              1.0
#                                             0.01                               2.0
#                                             0.05                               2.0
#                                             0.1                                NaN
#                                             0.25                               NaN
#
#                                                                                      \
#
# variant_key                                                         10-43595968-A-G
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               NaN
#                                             0.01                                2.0
#                                             0.05                                2.0
#                                             0.1                                 2.0
#                                             0.25                                2.0
#
#                                                                                      \
#
# variant_key                                                         10-43604493-C-T
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               2.0
#                                             0.01                                2.0
#                                             0.05                                2.0
#                                             0.1                                 2.0
#                                             0.25                                2.0
#
#                                                                                      \
#
# variant_key                                                         10-43613843-G-T
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               2.0
#                                             0.01                                2.0
#                                             0.05                                2.0
#                                             0.1                                 2.0
#                                             0.25                                2.0
#
#                                                                                      \
#
# variant_key                                                         12-25398281-C-T
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               NaN
#                                             0.01                                2.0
#                                             0.05                                2.0
#                                             0.1                                 2.0
#                                             0.25                                2.0
#
#                                                                           ...         \
#                                                                           ...
# variant_key                                                               ...
# sample_name                                 variant_downsample_rate       ...
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                         ...
#                                             0.01                          ...
#                                             0.05                          ...
#                                             0.1                           ...
#                                             0.25                          ...
#
#                                                                                mean  \
#                                                                                  DP
# variant_key                                                         6-117718110-C-T
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               9.0
#                                             0.01                               15.0
#                                             0.05                               51.5
#                                             0.1                               117.0
#                                             0.25                              263.0
#
#                                                                                       \
#
# variant_key                                                         7-116339847-GT-G
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               13.0
#                                             0.01                                 NaN
#                                             0.05                               102.0
#                                             0.1                                187.0
#                                             0.25                               443.5
#
#                                                                                      \
#
# variant_key                                                         7-116436022-G-A
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               NaN
#                                             0.01                                NaN
#                                             0.05                               86.5
#                                             0.1                               179.0
#                                             0.25                              444.5
#
#                                                                                      \
#
# variant_key                                                         7-140453136-A-T
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                               NaN
#                                             0.01                               20.0
#                                             0.05                               80.0
#                                             0.1                               158.0
#                                             0.25                              398.5
#
#                                                                                     \
#
# variant_key                                                         7-55241707-G-A
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                              8.0
#                                             0.01                              13.0
#                                             0.05                              70.0
#                                             0.1                              148.5
#                                             0.25                             380.0
#
#                                                                                                    \
#
# variant_key                                                         7-55242464-AGGAATTAAGAGAAGC-A
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                                             NaN
#                                             0.01                                              NaN
#                                             0.05                                              NaN
#                                             0.1                                               NaN
#                                             0.25                                            370.5
#
#                                                                                     \
#
# variant_key                                                         7-55249063-G-A
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                             14.0
#                                             0.01                              17.0
#                                             0.05                              91.0
#                                             0.1                              185.5
#                                             0.25                             415.0
#
#                                                                                     \
#
# variant_key                                                         7-55259515-T-G
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                              NaN
#                                             0.01                               NaN
#                                             0.05                              88.0
#                                             0.1                              185.5
#                                             0.25                             461.5
#
#                                                                                     \
#
# variant_key                                                         X-66765627-G-A
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                              4.0
#                                             0.01                              13.5
#                                             0.05                              56.0
#                                             0.1                              124.0
#                                             0.25                             326.0
#
#
#
# variant_key                                                         X-76938088-GTC-G
# sample_name                                 variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                                7.0
#                                             0.01                                15.5
#                                             0.05                                55.5
#                                             0.1                                120.5
#                                             0.25                               295.0
#
# [5 rows x 152 columns]

# %%
final_variant_df = pivoted_df.transpose()

# %%
# Depth calculations

# %%
depth_csvs = glob.glob('../output/depth/*.txt')

master_depth_df = pd.DataFrame()

for file in depth_csvs:
    
    new_df = pd.read_csv(file, sep='\t')
    
    new_df['file_name'] = file
        
    master_depth_df = master_depth_df.append(new_df)

# %%
master_depth_df.head()
# Out:
#   # chrom  chromStart  chromEnd                F3  readCount  meanCoverage  \
# 0       1      836813    836885  rs_id:rs28705752          4      2.277780
# 1       1     1338988   1339057  rs_id:rs17363048          4      3.739130
# 2       1     1891966   1892044   rs_id:rs2803292          5      3.692310
# 3       1     2402506   2402581   rs_id:rs2494627          1      0.653333
# 4       1     2943184   2943263   rs_id:rs7412983          8      3.886080
#
#     sampleName                                          file_name
# 0  18M05126-OS  ../output/depth/180920_NB551319_0007_AH5GNLAFX...
# 1  18M05126-OS  ../output/depth/180920_NB551319_0007_AH5GNLAFX...
# 2  18M05126-OS  ../output/depth/180920_NB551319_0007_AH5GNLAFX...
# 3  18M05126-OS  ../output/depth/180920_NB551319_0007_AH5GNLAFX...
# 4  18M05126-OS  ../output/depth/180920_NB551319_0007_AH5GNLAFX...

# %%
master_depth_df['sample'] = master_depth_df.apply(get_sample_name,axis=1)

# %%
master_depth_df['variant_downsample_rate'] = master_depth_df.apply(get_variant_down_sample_rate, axis=1)

# %%
master_depth_df.head()
# Out:
#   # chrom  chromStart  chromEnd                F3  readCount  meanCoverage  \
# 0       1      836813    836885  rs_id:rs28705752          4      2.277780
# 1       1     1338988   1339057  rs_id:rs17363048          4      3.739130
# 2       1     1891966   1892044   rs_id:rs2803292          5      3.692310
# 3       1     2402506   2402581   rs_id:rs2494627          1      0.653333
# 4       1     2943184   2943263   rs_id:rs7412983          8      3.886080
#
#     sampleName                                          file_name  \
# 0  18M05126-OS  ../output/depth/180920_NB551319_0007_AH5GNLAFX...
# 1  18M05126-OS  ../output/depth/180920_NB551319_0007_AH5GNLAFX...
# 2  18M05126-OS  ../output/depth/180920_NB551319_0007_AH5GNLAFX...
# 3  18M05126-OS  ../output/depth/180920_NB551319_0007_AH5GNLAFX...
# 4  18M05126-OS  ../output/depth/180920_NB551319_0007_AH5GNLAFX...
#
#                                         sample variant_downsample_rate
# 0  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS                   0.005
# 1  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS                   0.005
# 2  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS                   0.005
# 3  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS                   0.005
# 4  180920_NB551319_0007_AH5GNLAFXY_18M05126-OS                   0.005

# %%
master_depth_df.groupby(['sample','variant_downsample_rate'] ).mean()
# Out:
#                                                                        chromStart  \
# sample                                      variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                    7.128307e+07
#                                             0.01                     7.128307e+07
#                                             0.05                     7.128307e+07
#                                             0.1                      7.128307e+07
#                                             0.25                     7.128307e+07
#                                             0.5                      7.128307e+07
#
#                                                                          chromEnd  \
# sample                                      variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                    7.128320e+07
#                                             0.01                     7.128320e+07
#                                             0.05                     7.128320e+07
#                                             0.1                      7.128320e+07
#                                             0.25                     7.128320e+07
#                                             0.5                      7.128320e+07
#
#                                                                        readCount  \
# sample                                      variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                      12.852195
#                                             0.01                       25.817073
#                                             0.05                      128.765366
#                                             0.1                       258.190244
#                                             0.25                      645.671220
#                                             0.5                      1292.456098
#
#                                                                      meanCoverage
# sample                                      variant_downsample_rate
# 180920_NB551319_0007_AH5GNLAFXY_18M05126-OS 0.005                        4.698138
#                                             0.01                         9.439538
#                                             0.05                        46.814478
#                                             0.1                         94.093112
#                                             0.25                       235.500192
#                                             0.5                        471.267953

# %%
final_variant_df
# Out:
# sample_name                            180920_NB551319_0007_AH5GNLAFXY_18M05126-OS  \
# variant_downsample_rate                                                      0.005
#          variant_key
# count DP 1-115256530-G-T                                                       1.0
#          1-156846233-G-A                                                       1.0
#          1-156846307-GC-G                                                      2.0
#          1-156848995-C-T                                                       2.0
#          1-27056285-G-A                                                        NaN
#          1-27100181-C-T                                                        1.0
#          10-43595968-A-G                                                       NaN
#          10-43604493-C-T                                                       2.0
#          10-43613843-G-T                                                       2.0
#          12-25398281-C-T                                                       NaN
#          12-25398284-C-T                                                       NaN
#          13-32911888-A-G                                                       1.0
#          13-32912299-T-C                                                       NaN
#          13-32912750-G-T                                                       NaN
#          13-32913558-CA-C                                                      NaN
#          13-32913836-CA-C                                                      2.0
#          15-88576185-G-C                                                       1.0
#          15-88680684-G-A                                                       2.0
#          17-37879588-A-G                                                       2.0
#          17-41234451-G-A                                                       NaN
#          17-7579472-G-C                                                        2.0
#          3-178936091-G-A                                                       NaN
#          3-178947865-G-A                                                       NaN
#          3-178952085-A-G                                                       1.0
#          4-55152040-C-T                                                        NaN
#          4-55599321-A-T                                                        NaN
#          6-117678083-A-G                                                       1.0
#          6-117686840-T-C                                                       NaN
#          6-117718110-C-T                                                       1.0
#          7-116339847-GT-G                                                      1.0
# ...                                                                            ...
# mean  DP 10-43613843-G-T                                                       6.0
#          12-25398281-C-T                                                       NaN
#          12-25398284-C-T                                                       NaN
#          13-32911888-A-G                                                       8.0
#          13-32912299-T-C                                                       NaN
#          13-32912750-G-T                                                       NaN
#          13-32913558-CA-C                                                      NaN
#          13-32913836-CA-C                                                      6.0
#          15-88576185-G-C                                                       6.0
#          15-88680684-G-A                                                      10.5
#          17-37879588-A-G                                                       8.5
#          17-41234451-G-A                                                       NaN
#          17-7579472-G-C                                                        5.0
#          3-178936091-G-A                                                       NaN
#          3-178947865-G-A                                                       NaN
#          3-178952085-A-G                                                       8.0
#          4-55152040-C-T                                                        NaN
#          4-55599321-A-T                                                        NaN
#          6-117678083-A-G                                                       3.0
#          6-117686840-T-C                                                       NaN
#          6-117718110-C-T                                                       9.0
#          7-116339847-GT-G                                                     13.0
#          7-116436022-G-A                                                       NaN
#          7-140453136-A-T                                                       NaN
#          7-55241707-G-A                                                        8.0
#          7-55242464-AGGAATTAAGAGAAGC-A                                         NaN
#          7-55249063-G-A                                                       14.0
#          7-55259515-T-G                                                        NaN
#          X-66765627-G-A                                                        4.0
#          X-76938088-GTC-G                                                      7.0
#
# sample_name
# variant_downsample_rate                 0.01   0.05    0.1   0.25    0.5
#          variant_key
# count DP 1-115256530-G-T                 NaN    2.0    2.0    2.0    2.0
#          1-156846233-G-A                 2.0    2.0    2.0    2.0    2.0
#          1-156846307-GC-G                2.0    2.0    2.0    2.0    2.0
#          1-156848995-C-T                 2.0    2.0    2.0    2.0    2.0
#          1-27056285-G-A                  2.0    2.0    2.0    2.0    2.0
#          1-27100181-C-T                  2.0    2.0    NaN    NaN    NaN
#          10-43595968-A-G                 2.0    2.0    2.0    2.0    2.0
#          10-43604493-C-T                 2.0    2.0    2.0    2.0    2.0
#          10-43613843-G-T                 2.0    2.0    2.0    2.0    2.0
#          12-25398281-C-T                 2.0    2.0    2.0    2.0    2.0
#          12-25398284-C-T                 NaN    NaN    2.0    2.0    2.0
#          13-32911888-A-G                 2.0    2.0    2.0    2.0    2.0
#          13-32912299-T-C                 1.0    2.0    2.0    2.0    2.0
#          13-32912750-G-T                 2.0    2.0    2.0    2.0    2.0
#          13-32913558-CA-C                1.0    2.0    2.0    2.0    2.0
#          13-32913836-CA-C                2.0    2.0    2.0    2.0    2.0
#          15-88576185-G-C                 2.0    2.0    2.0    2.0    2.0
#          15-88680684-G-A                 2.0    2.0    2.0    2.0    2.0
#          17-37879588-A-G                 2.0    2.0    2.0    2.0    2.0
#          17-41234451-G-A                 2.0    2.0    2.0    2.0    2.0
#          17-7579472-G-C                  2.0    2.0    2.0    2.0    2.0
#          3-178936091-G-A                 NaN    2.0    2.0    2.0    2.0
#          3-178947865-G-A                 1.0    2.0    2.0    2.0    2.0
#          3-178952085-A-G                 2.0    2.0    2.0    2.0    2.0
#          4-55152040-C-T                  1.0    2.0    2.0    2.0    2.0
#          4-55599321-A-T                  1.0    2.0    2.0    2.0    2.0
#          6-117678083-A-G                 2.0    2.0    2.0    2.0    2.0
#          6-117686840-T-C                 2.0    2.0    2.0    2.0    2.0
#          6-117718110-C-T                 2.0    2.0    2.0    2.0    2.0
#          7-116339847-GT-G                NaN    1.0    1.0    2.0    2.0
# ...                                      ...    ...    ...    ...    ...
# mean  DP 10-43613843-G-T                17.5   71.0  149.0  414.5  755.5
#          12-25398281-C-T                12.5   58.5  120.5  300.0  585.5
#          12-25398284-C-T                 NaN    NaN  118.0  291.5  579.5
#          13-32911888-A-G                15.0   59.5  116.0  313.5  592.5
#          13-32912299-T-C                15.0   59.0  107.5  288.0  589.0
#          13-32912750-G-T                 8.5   47.0   96.0  272.5  567.0
#          13-32913558-CA-C                7.0   51.0  116.5  283.5  589.5
#          13-32913836-CA-C               11.0   53.5  127.5  313.0  602.0
#          15-88576185-G-C                11.0   65.0  136.5  375.5  684.0
#          15-88680684-G-A                13.5   63.5  140.0  355.5  701.5
#          17-37879588-A-G                20.0   69.0  134.5  272.5  601.0
#          17-41234451-G-A                 9.5   56.5  112.5  293.0  576.0
#          17-7579472-G-C                 15.0   70.5  136.5  359.0  698.0
#          3-178936091-G-A                 NaN   48.5  106.5  281.5  542.5
#          3-178947865-G-A                 9.0   55.5  122.0  295.5  624.0
#          3-178952085-A-G                13.0   57.5  109.0  268.0  512.5
#          4-55152040-C-T                  5.0   67.5  106.0  302.5  604.5
#          4-55599321-A-T                 19.0   45.0   99.5  260.0  518.5
#          6-117678083-A-G                 8.0   38.0   73.5  177.5  371.0
#          6-117686840-T-C                15.0   56.5  103.5  276.0  531.5
#          6-117718110-C-T                15.0   51.5  117.0  263.0  516.5
#          7-116339847-GT-G                NaN  102.0  187.0  443.5  928.5
#          7-116436022-G-A                 NaN   86.5  179.0  444.5  857.0
#          7-140453136-A-T                20.0   80.0  158.0  398.5  811.0
#          7-55241707-G-A                 13.0   70.0  148.5  380.0  788.5
#          7-55242464-AGGAATTAAGAGAAGC-A   NaN    NaN    NaN  370.5  783.5
#          7-55249063-G-A                 17.0   91.0  185.5  415.0  834.5
#          7-55259515-T-G                  NaN   88.0  185.5  461.5  929.5
#          X-66765627-G-A                 13.5   56.0  124.0  326.0  627.5
#          X-76938088-GTC-G               15.5   55.5  120.5  295.0  596.5
#
# [152 rows x 6 columns]
